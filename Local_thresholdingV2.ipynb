# %%
import cv2
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd 
from skimage.data import page
from skimage.filters import (threshold_otsu, threshold_niblack,
                             threshold_sauvola)

# %%
def mousePoints(event, x, y, flags, params):
    if event == cv2.EVENT_LBUTTONDOWN:
        print(x,y)

# %% [markdown]
# # Name :

# %%
img = cv2.imread('data2/i11.jpg')
img2 = cv2.imread('data2/m1.jpeg')
img3 = cv2.imread('data2/i2.jpg')
img4 = cv2.imread('data2/i3.jpg')
img5 = cv2.imread('data2/m2.jpeg')
img6 = cv2.imread('data2/m3.jpeg')
img7 = cv2.imread('data2/m10.jpeg')
img8 = cv2.imread('data2/m6.jpeg')
img9 = cv2.imread('data2/i2.jpg')
img10 = cv2.imread('data2/m8.jpeg')
#44
#77
while True : 
    
    
    cv2.imshow('img5', img5)
    cv2.setMouseCallback('img5', mousePoints)

    
    k = cv2.waitKey(1) & 0xFF
    if k == 27: 
        break
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-8-299a2c25b5d2> in <module>
#      14
#      15
# ---> 16     cv2.imshow('img5', img5)
#      17     cv2.setMouseCallback('img5', mousePoints)
#      18
#
# error: OpenCV(4.4.0) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-1hg9yufe\opencv\modules\highgui\src\window.cpp:376: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'

# %%
width, height = 250, 300



#Male/Female
a = 540
b = 550
c = 613
d = 619

image = img.copy()

pts1 = np.float32([[a, b], [c, b], [a, d], [c, d]])

pts = np.float32([[0, 0], [width, 0], [0, height], [width, height]])

matrix = cv2.getPerspectiveTransform(pts1, pts)

imgOutput = cv2.warpPerspective(img, matrix, (width, height))
imgOutput2 = cv2.warpPerspective(img2, matrix, (width, height))
imgOutput3 = cv2.warpPerspective(img3, matrix, (width, height))
imgOutput4 = cv2.warpPerspective(img4, matrix, (width, height))
imgOutput5 = cv2.warpPerspective(img5, matrix, (width, height))
imgOutput6 = cv2.warpPerspective(img6, matrix, (width, height))
imgOutput7 = cv2.warpPerspective(img7, matrix, (width, height))
imgOutput8 = cv2.warpPerspective(img8, matrix, (width, height))
imgOutput9 = cv2.warpPerspective(img9, matrix, (width, height))
imgOutput10 = cv2.warpPerspective(img10, matrix, (width, height))

cv2.rectangle(img, (a, b), (c, d),(0, 0, 255), 2)
cv2.rectangle(img2, (a, b), (c, d),(0, 0, 255), 2)
cv2.rectangle(img3, (a, b), (c, d),(0, 0, 255), 2)
cv2.rectangle(img4, (a, b), (c, d),(0, 0, 255), 2)
cv2.rectangle(img5, (a, b), (c, d),(0, 0, 255), 2)
cv2.rectangle(img6, (a, b), (c, d),(0, 0, 255), 2)
cv2.rectangle(img7, (a, b), (c, d),(0, 0, 255), 2)
cv2.rectangle(img8, (a, b), (c, d),(0, 0, 255), 2)
cv2.rectangle(img9, (a, b), (c, d),(0, 0, 255), 2)
cv2.rectangle(img10, (a, b), (c, d),(0, 0, 255), 2)

'''

while True : 

    
    cv2.imshow('original', image)
    cv2.imshow('Output', imgOutput)
    cv2.imshow('marked', marked)

    
    k = cv2.waitKey(1) & 0xFF
    if k == 27: 
        break
cv2.destroyAllWindows() 
'''
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-afe5c12b9c59> in <module>
#       9 d = 619
#      10
# ---> 11 image = img.copy()
#      12
#      13 pts1 = np.float32([[a, b], [c, b], [a, d], [c, d]])
#
# AttributeError: 'NoneType' object has no attribute 'copy'

# %%
titles = [ 'id1', 'id2', 'id3', 'id4', 'id5', 'id6', 'id7', 'id8','id9', 'id10']  #,'marked']
images = [ imgOutput, imgOutput2, imgOutput3, imgOutput4, imgOutput5, imgOutput6, imgOutput7, imgOutput8, imgOutput9, imgOutput10] #, marked]

#plt.figure(figsize=(30,30))
#plt.imshow(image)
#f.add_subplot(3, 3, i+1)

# %%
plt.figure(figsize=(15,15))
for i in range (10):
    
    #f.add_subplot(3, 3, i+1),  plt.imshow(images[i], 'gray')
    plt.subplot(2, 5, i+1),  plt.imshow(images[i], 'gray')
    plt.title(titles[i])
    plt.xticks([]), plt.yticks([])
plt.show()

# %%
plt.imshow(images[4])

# %%
images[0].shape
# Out:
# (300, 250, 3)

# %%
image = [[[0 for k in range(10)] for j in range(250)] for i in range(231)]
for i in range(10):
    image[i] = cv2.cvtColor(images[i], cv2.cv2.COLOR_BGR2GRAY)

# %%
import mahotas
import cv2
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

# %%
kernel = np.ones((5,5), np.uint8) 


# Taking a matrix of size 5 as the kernel 

img_erosion1 = cv2.erode(image[0], kernel, iterations=1) 
img_dilation1 = cv2.dilate(image[0], kernel, iterations=1) 
img_erosion2 = cv2.erode(image[1], kernel, iterations=1) 
img_dilation2 = cv2.dilate(image[1], kernel, iterations=1) 
img_erosion3 = cv2.erode(image[2], kernel, iterations=1) 
img_dilation3 = cv2.dilate(image[2], kernel, iterations=1) 
img_erosion4 = cv2.erode(image[3], kernel, iterations=1) 
img_dilation4 = cv2.dilate(image[3], kernel, iterations=1) 

img_erosion5 = cv2.erode(image[4], kernel, iterations=1) 
img_dilation5 = cv2.dilate(image[4], kernel, iterations=1) 
img_erosion6 = cv2.erode(image[5], kernel, iterations=1) 
img_dilation6 = cv2.dilate(image[5], kernel, iterations=1) 
img_erosion7= cv2.erode(image[6], kernel, iterations=1) 
img_dilation7 = cv2.dilate(image[6], kernel, iterations=1) 
img_erosion8 = cv2.erode(image[7], kernel, iterations=1) 
img_dilation8 = cv2.dilate(image[7], kernel, iterations=1) 

img_erosion9 = cv2.erode(image[8], kernel, iterations=1) 
img_dilation9 = cv2.dilate(image[8], kernel, iterations=1) 
img_erosion10 = cv2.erode(image[9], kernel, iterations=1) 
img_dilation10 = cv2.dilate(image[9], kernel, iterations=1)

# %%
img_dilation = [ img_dilation1, img_dilation2, img_dilation3, img_dilation4, img_dilation5, img_dilation6, img_dilation7, img_dilation8, img_dilation9, img_dilation10]
img_erosion = [ img_erosion1, img_erosion2, img_erosion3, img_erosion4, img_erosion5, img_erosion6, img_erosion7,img_erosion8, img_erosion9,img_erosion10, ]

# %%
plt.figure(figsize=(15,15))

    
    #f.add_subplot(3, 3, i+1),  plt.imshow(images[i], 'gray')
plt.imshow(img_dilation[9], 'gray')
plt.title('iMage after dilation')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ## Filter:

# %%
def do_nothing(x):
    pass

# %%
img_dilation0.size
# Out:
# 75000

# %%
#blurred = cv2.GaussianBlur(image, (17, 17), 0)
blurred = [[[0 for k in range(10)] for j in range(252)] for i in range(231)]
for i in range(10):
    

    blurred[i] = cv2.bilateralFilter(img_dilation[i], 10, 31, 31)

# %%
blurred9 = cv2.bilateralFilter(images[i], 10, 31, 31)

# %%
dilat = cv2.dilate(blurred9, kernel, iterations=1)

# %%
plt.figure(figsize=(15,15))

    
    #f.add_subplot(3, 3, i+1),  plt.imshow(images[i], 'gray')
plt.imshow(thresh, 'gray')
plt.title('iMage after filter')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
plt.figure(figsize=(15,15))
for i in range (10):
    
    #f.add_subplot(3, 3, i+1),  plt.imshow(images[i], 'gray')
    plt.subplot(2, 5, i+1),  plt.imshow(img_dilation[i],'gray')
#    plt.title(titles[i])
    plt.xticks([]), plt.yticks([])
plt.show()

# %%
plt.figure(figsize=(15,15))
for i in range (10):
    
    #f.add_subplot(3, 3, i+1),  plt.imshow(images[i], 'gray')
    plt.subplot(2, 5, i+1),  plt.imshow(blurred[i],'gray')
#    plt.title(titles[i])
    plt.xticks([]), plt.yticks([])
plt.show()

# %%
plt.figure(figsize=(15,15))

    
    #f.add_subplot(3, 3, i+1),  plt.imshow(images[i], 'gray')
plt.imshow(blurred[9], 'gray')
plt.title('iMage after bilatiral')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
image[0].shape
# Out:
# (300, 250)

# %% [markdown]
# ## Otsu and Riddle calvard:

# %%
opening = cv2.morphologyEx(orig_image2, cv2.MORPH_OPEN, kernel)

# %%
T = np.zeros(10)
copy2 = [[[0 for k in range(10)] for j in range(252)] for i in range(231)]
for i in range (10):
    T[i] = mahotas.thresholding.rc(img_erosion[i])
    print("Riddler-Calvard: {}".format(T[i]))
    copy2[i] = image[i].copy()
    copy2[i][copy2[i] > T[i]] = 255
    copy2[i][copy2[i] < T[i]] = 0
#copy2 = cv2.bitwise_and(copy2)
# Out:
# Riddler-Calvard: 76.74002270915744
# Riddler-Calvard: 76.74002270915744
# Riddler-Calvard: 157.88099519980307
# Riddler-Calvard: 142.8079127681976
# Riddler-Calvard: 93.67716185436383
# Riddler-Calvard: 151.82366119584387
# Riddler-Calvard: 138.84332817430004
# Riddler-Calvard: 178.5451107002532
# Riddler-Calvard: 145.56410927157322
# Riddler-Calvard: 142.8079127681976

# %%
plt.figure(figsize=(15,15))
for i in range (10):
    
    #f.add_subplot(3, 3, i+1),  plt.imshow(images[i], 'gray')
    plt.subplot(2, 5, i+1),  plt.imshow(copy2[i],'gray')
#    plt.title(titles[i])
    plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ## Adaptive thresholding:

# %%
def adaptive_thresholding(use_blur=False, mean=True, inverse=False, blockSize=11, C=5):
    if mean:
        if inverse:
            if use_blur:
                b_atm_inv = cv2.adaptiveThreshold(blurred[i],
                                                  255, cv2.ADAPTIVE_THRESH_MEAN_C,
                                                  cv2.THRESH_BINARY_INV, blockSize, C)

                return b_atm_inv

            else:
                atm_inv = cv2.adaptiveThreshold(dilat,
                                                255, cv2.ADAPTIVE_THRESH_MEAN_C,
                                                cv2.THRESH_BINARY_INV, blockSize, C)
                return atm_inv

        else:
            if use_blur:
                b_atm = cv2.adaptiveThreshold(blurred[i],
                                              255, cv2.ADAPTIVE_THRESH_MEAN_C,
                                              cv2.THRESH_BINARY, blockSize, C)

                return b_atm

            else:
                atm = cv2.adaptiveThreshold(image[i],
                                            255, cv2.ADAPTIVE_THRESH_MEAN_C,
                                            cv2.THRESH_BINARY, blockSize, C)

                return atm

    else:
        if inverse:
            if use_blur:
                b_atg_inv = cv2.adaptiveThreshold(blurred[i],
                                                  255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                                  cv2.THRESH_BINARY_INV, blockSize, C)

                return b_atg_inv

            else:
                atg_inv = cv2.adaptiveThreshold(image[i],
                                                255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                                cv2.THRESH_BINARY_INV, blockSize, C)

                return atg_inv

        else:
            if use_blur:
                b_atg = cv2.adaptiveThreshold(blurred[i],
                                              255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                              cv2.THRESH_BINARY, blockSize, C)
                return b_atg

            else:
                atg = cv2.adaptiveThreshold(image[i],
                                            255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                            cv2.THRESH_BINARY, blockSize, C)
                return atg

# %%
#* Examine ADAPTIVE THRESHOLDING  #
threshold_image = [[[0 for k in range(10)] for j in range(252)] for i in range(231)]

for i in range(10):

    threshold_image[i] = adaptive_thresholding(mean=True, inverse=False,
                                            use_blur=True, blockSize =33, C=10)

# %%
thresh = adaptive_thresholding(mean=True, inverse=False,
                                            use_blur=False, blockSize =33, C=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2af029d4bb5b> in <module>
# ----> 1 thresh = adaptive_thresholding(mean=True, inverse=False,
#       2                                             use_blur=False, blockSize =33, C=11)
#
# NameError: name 'adaptive_thresholding' is not defined

# %%
titles2 = [ 'Binarization id1', 'Binarization id2', 'Binarization id3', 'Binarization id4', 'Binarization id5', 'Binarization id6', 'Binarization id7', 'Binarization id8','Binarization id9', 'Binarization id10']  #,'marked']


plt.figure(figsize=(15,15))
for i in range (10):  
    plt.subplot(2, 5, i+1),  plt.imshow(threshold_image[i],'gray')
    plt.title(titles2[i])

    plt.xticks([]), plt.yticks([])
plt.show()

# %%
plt.figure(figsize=(15,15))

    
    #f.add_subplot(3, 3, i+1),  plt.imshow(images[i], 'gray')
plt.imshow(threshold_image[9], 'gray')
plt.title('iMage after Adabtive mean threshold without bilateral filter')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ## Nilack and sauvola:

# %%
import matplotlib
import matplotlib.pyplot as plt
binary_sauvola = [[[0 for k in range(10)] for j in range(252)] for i in range(231)]
binary_niblack = [[[0 for k in range(10)] for j in range(252)] for i in range(231)]

thresh_sauvola = [[[0 for k in range(10)] for j in range(252)] for i in range(231)]
thresh_niblack = [[[0 for k in range(10)] for j in range(252)] for i in range(231)]
for i in range(10):
    

    #binary_global = image1 > threshold_otsu(image1)

    window_size = 27
    thresh_niblack[i] = threshold_niblack(blurred[i], window_size=window_size, k=1)
    thresh_sauvola[i] = threshold_sauvola(blurred[i], window_size=41)

    binary_niblack[i] = blurred[i] > thresh_niblack[i]
    binary_sauvola[i] = blurred[i] > thresh_sauvola[i]

# %%
plt.figure(figsize=(15,15))
for i in range (10):
    plt.title("Binarization images")
    #plt.xlabel("# of pixels")
    #plt.ylabel("bins")
    #f.add_subplot(3, 3, i+1),  plt.imshow(images[i], 'gray')
    plt.subplot(2, 5, i+1)
    plt.imshow(binary_sauvola[i],cmap=plt.cm.gray)
#    plt.title(titles[i])
    plt.xticks([]), plt.yticks([])
plt.show()

# %%
blpx_in_each_row = [0 for k in range(10)]

bl_pixels = [0 for k in range(10)]
output = [0 for k in range(10)]

# %%
for i in range (10):
    

    blpx_in_each_row[i] = []
    for x in range(np.asarray(threshold_image[i]).shape[0]):         #height       
        bl_pixels[i]=0
        for y in range(np.asarray(threshold_image[i]).shape[1]):     #width
            if threshold_image[i][x,y] == 0:
                bl_pixels[i] = bl_pixels[i]+1     #counting no. of black pixels in each row
        blpx_in_each_row[i].append(bl_pixels[i])  

        output[i] = np.zeros([np.asarray(threshold_image[i]).shape[0],np.asarray(threshold_image[i]).shape[1]]) 
    height = np.max(blpx_in_each_row[0])       #baseline   
    width = threshold_image[0].shape[1]
    for row in range(np.asarray(threshold_image[i]).shape[0]):       #for each row in input image draw a white line
        col = int(blpx_in_each_row[i][row]*width/height)
        cv2.line(output[i], (255,row), (col,row), (255,255,255), 1)

# %%
plt.figure(figsize=(15,15))
titles3 =  [ 'Horiz Histogram id1', 'Horiz Histogram id2', 'Horiz Histogram id3', 'Horiz Histogram id4', 'Horiz Histogram id5', 'Horiz Histogram id6', 'Horiz Histogram id7', 'Horiz Histogram id8','Horiz Histogram id9', 'Horiz Histogram id10']

for i in range (10):


    #    plt.figure()
    plt.subplot(2, 5, i+1),  plt.imshow(output[i], 'gray', extent=(0,500,0,500))
    plt.title(titles3[i])
    plt.xlabel("# of pixels")
    plt.ylabel("bins")

#    plt.title(titles[i])
    plt.xticks([]), plt.yticks([])
    
    
plt.show()

# %%
opening = cv2.morphologyEx(orig_image2, cv2.MORPH_OPEN, kernel)

# %%
blpx_in_each_col = [0 for k in range(10)]

bl_pixels2 = [0 for k in range(10)]
output2 = [0 for k in range(10)]

# %%
for i in range (10):
    

    blpx_in_each_col[i] = []
    for x in range(np.asarray(threshold_image[i]).shape[1]):         #height       
        bl_pixels2[i]=0
        for y in range(np.asarray(threshold_image[i]).shape[0]):     #width
            if np.asarray(threshold_image[i])[y,x] == 0:
                bl_pixels2[i] = bl_pixels2[i]+1     #counting no. of black pixels in each row
                
        blpx_in_each_col[i].append(bl_pixels2[i])  

        output2[i] = np.zeros([np.asarray(threshold_image[i]).shape[0],np.asarray(threshold_image[i]).shape[1]]) 
    width = np.max(blpx_in_each_col[0])+500       #baseline   
    height = np.asarray(threshold_image[i])[0].shape[0] 
    for col in range(np.asarray(threshold_image[i]).shape[1]):       #for each row in input image draw a white line
        row = int(blpx_in_each_col[i][col]*width/height)
        cv2.line(output2[i], (col,255), (col,row), (255,255,255), 1)

# %%
plt.figure(figsize=(20,20))
titles3 =  [ 'Vertical Histogram id1', 'Vertical Histogram id2', 'Vertical Histogram id3', 'Vertical Histogram id4', 'Vertical Histogram id5', 'Vertical Histogram id6', 'Vertical Histogram id7', 'Vertical Histogram id8','Vertical Histogram id9', 'Vertical Histogram id10']

for i in range (10):
        
    plt.title("Vertical Histogram")
    plt.xlabel("bins")
    plt.ylabel("# of pixels")

    #f.add_subplot(3, 3, i+1),  plt.imshow(images[i], 'gray')
    plt.subplot(2, 5, i+1),  plt.imshow(output2[i], 'gray')
    #plt.title(titles[i])
    plt.xticks([]), plt.yticks([])
plt.show()

# %%
np.sum(blpx_in_each_row[1])
# Out:
# 3578

# %%
for i in range(10):
    print('\n ID number {}'.format(i+1))
    print('length of Horiz :{}'.format(len(blpx_in_each_row[i])),'\n length of verti:{}'.format(len(blpx_in_each_col[i])),'\n Max of Horiz:{}'.format(max(blpx_in_each_row[i])),'\n Max of Vertical:{}'.format(max(blpx_in_each_col[i])))
    print(' number of pixels : {} '.format(sum(blpx_in_each_row[i])))
# Out:
#  ID number 1
# length of Horiz :300
#  length of verti:250
#  Max of Horiz:84
#  Max of Vertical:55
#  number of pixels : 3453
#
#  ID number 2
# length of Horiz :300
#  length of verti:250
#  Max of Horiz:84
#  Max of Vertical:55
#  number of pixels : 3453
#
#  ID number 3
# length of Horiz :300
#  length of verti:250
#  Max of Horiz:73
#  Max of Vertical:57
#  number of pixels : 3738
#
#  ID number 4
# length of Horiz :300
#  length of verti:250
#  Max of Horiz:85
#  Max of Vertical:59
#  number of pixels : 3052
#
#  ID number 5
# length of Horiz :300
#  length of verti:250
#  Max of Horiz:73
#  Max of Vertical:57
#  number of pixels : 3225
#
#  ID number 6
# length of Horiz :300
#  length of verti:250
#  Max of Horiz:82
#  Max of Vertical:64
#  number of pixels : 4005
#
#  ID number 7
# length of Horiz :300
#  length of verti:250
#  Max of Horiz:83
#  Max of Vertical:69
#  number of pixels : 3752
#
#  ID number 8
# length of Horiz :300
#  length of verti:250
#  Max of Horiz:77
# ...
